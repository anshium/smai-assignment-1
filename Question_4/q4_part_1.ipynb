# %% [markdown]
# # SLIC

# %% [markdown]
# ### Refer to the article and implement SLIC from scratch.

# %%
from q4_random_centers import *

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Try to segment the image frame 0000.jpg. Alternatively, choose any image and try segmentation/superpixalation for it using SLIC.

# %%
def do_slic(image_path, num_segments, compactness, only_one_image=False):
    image = cv2.imread(image_path)
    # image = cv2.imread("/home/anshium/workspace/courses/smai/smai-assignment-1/Question_5/more_images/SLIC/2.jpg")
    # image = cv2.imread("/home/anshium/Pictures/wallpapers/Fantasy-Lake2.png")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)

    slic = SLIC(image, num_segments=num_segments, compactness=compactness)

    slic.iterate()
    segmentation = slic.get_segmentation()

    segmentation_bgr = cv2.cvtColor(segmentation, cv2.COLOR_LAB2BGR)
    # cv2.imwrite("segmentation.jpg", segmentation_bgr)

    segmentation_rgb = cv2.cvtColor(segmentation_bgr, cv2.COLOR_BGR2RGB)

    if(only_one_image):
        plt.figure(figsize=(8, 8))
        plt.imshow(segmentation_rgb)
        plt.axis("off")
        plt.title("Segmented Image")
        plt.show()

    return segmentation_rgb

# %%
image_path = "data/frame_0000.jpg"

do_slic(image_path, 100, 20, True)
# Out:
# array([[[115,  90,  69],
#         [115,  90,  69],
#         [115,  90,  69],
#         ...,
#         [124, 111,  16],
#         [124, 111,  16],
#         [124, 111,  16]],
#
#        [[115,  90,  69],
#         [115,  90,  69],
#         [115,  90,  69],
#         ...,
#         [124, 111,  16],
#         [124, 111,  16],
#         [124, 111,  16]],
#
#        [[115,  90,  69],
#         [115,  90,  69],
#         [115,  90,  69],
#         ...,
#         [124, 111,  16],
#         [124, 111,  16],
#         [124, 111,  16]],
#
#        ...,
#
#        [[  0,  64, 194],
#         [  0,  64, 194],
#         [  0,  64, 194],
#         ...,
#         [ 40,  35,  32],
#         [ 40,  35,  32],
#         [ 40,  35,  32]],
#
#        [[  0,  64, 194],
#         [  0,  64, 194],
#         [  0,  64, 194],
#         ...,
#         [ 40,  35,  32],
#         [ 40,  35,  32],
#         [ 40,  35,  32]],
#
#        [[  0,  64, 194],
#         [  0,  64, 194],
#         [  0,  64, 194],
#         ...,
#         [ 40,  35,  32],
#         [ 40,  35,  32],
#         [ 40,  35,  32]]], dtype=uint8)

# %% [markdown]
# ### Change the two hyperparameters: number of clusters and compactness and report the difference they bring.

# %%
num_segments_values = [50, 100, 150, 200]
compactness_values = [5, 10, 20, 40]

fig, axs = plt.subplots(2, 4, figsize=(16, 8))

for i, num_segments in enumerate(num_segments_values):
    for j, compactness in enumerate(compactness_values):
        idx = i * 4 + j
        ax = axs[i, j]

        segmented_image = do_slic(image_path, num_segments, compactness)

        ax.imshow(segmented_image)
        ax.axis('off')
        ax.set_title(f"Segments: {num_segments}, Compactness: {compactness}")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 11
#       8 idx = i * 4 + j
#       9 ax = axs[i, j]
# ---> 11 segmented_image = do_slic(image_path, num_segments, compactness)
#      13 ax.imshow(segmented_image)
#      14 ax.axis('off')
#
# Cell In[6], line 9, in do_slic(image_path, num_segments, compactness, only_one_image)
#       5 image = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
#       7 slic = SLIC(image, num_segments=100, compactness=20.0)
# ----> 9 slic.iterate()
#      10 segmentation = slic.get_segmentation()
#      12 segmentation_bgr = cv2.cvtColor(segmentation, cv2.COLOR_LAB2BGR)
#
# File ~/workspace/courses/smai/smai-assignment-1/Question_5/q2_random_centers.py:116, in SLIC.iterate(self, max_iter, threshold)
#     113 prev_clusters = np.array(self.clusters)
#     114 self.update_clusters_vectorised()
# --> 116 self.update_centers()
#     118 # Compute residual error
#     119 residual_error = np.linalg.norm(prev_clusters - np.array(self.clusters))
#
# File ~/workspace/courses/smai/smai-assignment-1/Question_5/q2_random_centers.py:91, in SLIC.update_centers(self)
#      89 new_clusters = []
#      90 for k in range(len(self.clusters)):
# ---> 91     points = np.argwhere(self.labels == k)
#      92     if len(points) == 0:
#      93         new_clusters.append(self.clusters[k])
#
# File ~/miniconda3/envs/smai/lib/python3.10/site-packages/numpy/_core/numeric.py:651, in argwhere(a)
#     649     # then remove the added dimension
#     650     return argwhere(a)[:, :0]
# --> 651 return transpose(nonzero(a))
#
# File ~/miniconda3/envs/smai/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:2051, in nonzero(a)
#    1959 @array_function_dispatch(_nonzero_dispatcher)
#    1960 def nonzero(a):
#    1961     """
#    1962     Return the indices of the elements that are non-zero.
#    1963
#    (...)
#    2049
#    2050     """
# -> 2051     return _wrapfunc(a, 'nonzero')
#
# File ~/miniconda3/envs/smai/lib/python3.10/site-packages/numpy/_core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Display the image after every iteration to qualitatively see the change that happens in every iteration

# %% [markdown]
# ### As you can see the distance metric used is in Lab Space and not RGB space. Try out the RGB space and report any difference noticed. What might be the reason for it.

# %%
from q4_rgb_distance import *

# %%
import matplotlib.pyplot as plt

# %%
def do_slic_rgb(image_path, num_segments, compactness):
    image = cv2.imread(image_path)
    # image = cv2.imread("/home/anshium/workspace/courses/smai/smai-assignment-1/Question_5/more_images/SLIC/2.jpg")
    # image = cv2.imread("/home/anshium/Pictures/wallpapers/Fantasy-Lake2.png")
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)


    slic = SLIC_RGB(image, num_segments=num_segments, compactness=compactness)

    slic.iterate()
    segmentation = slic.get_segmentation()

    segmentation_bgr = cv2.cvtColor(segmentation, cv2.COLOR_RGB2BGR)
    segmentation_rgb = cv2.cvtColor(segmentation_bgr, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(8, 8))
    plt.imshow(segmentation_rgb)
    plt.axis("off")
    plt.title("Segmented Image")
    plt.show()


image_path_rgb = "data/frame_0000.jpg"
num_segments = 100
compactness = 20

do_slic_rgb(image_path_rgb, num_segments, compactness)
